  Test Accuracy: 0.831
# Epoch: 2/2..  Training Loss: 0.531..  Test Loss: 0.484..  Test Accuracy: 0.821
# Epoch: 2/2..  Training Loss: 0.538..  Test Loss: 0.473..  Test Accuracy: 0.825
# Epoch: 2/2..  Training Loss: 0.509..  Test Loss: 0.471..  Test Accuracy: 0.828
# Epoch: 2/2..  Training Loss: 0.518..  Test Loss: 0.479..  Test Accuracy: 0.827
# Epoch: 2/2..  Training Loss: 0.524..  Test Loss: 0.463..  Test Accuracy: 0.832
# Epoch: 2/2..  Training Loss: 0.559..  Test Loss: 0.460..  Test Accuracy: 0.830
# Epoch: 2/2..  Training Loss: 0.537..  Test Loss: 0.454..  Test Accuracy: 0.829
# Epoch: 2/2..  Training Loss: 0.534..  Test Loss: 0.467..  Test Accuracy: 0.827
# Epoch: 2/2..  Training Loss: 0.534..  Test Loss: 0.449..  Test Accuracy: 0.839
# Epoch: 2/2..  Training Loss: 0.520..  Test Loss: 0.469..  Test Accuracy: 0.830
# Epoch: 2/2..  Training Loss: 0.514..  Test Loss: 0.464..  Test Accuracy: 0.830
# Epoch: 2/2..  Training Loss: 0.525..  Test Loss: 0.444..  Test Accuracy: 0.831
# Epoch: 2/2..  Training Loss: 0.500..  Test Loss: 0.455..  Test Accuracy: 0.840
# Epoch: 2/2..  Training Loss: 0.567..  Test Loss: 0.454..  Test Accuracy: 0.838
# Epoch: 2/2..  Training Loss: 0.537..  Test Loss: 0.446..  Test Accuracy: 0.838
# Epoch: 2/2..  Training Loss: 0.500..  Test Loss: 0.439..  Test Accuracy: 0.840
# Epoch: 2/2..  Training Loss: 0.561..  Test Loss: 0.442..  Test Accuracy: 0.836
# Epoch: 2/2..  Training Loss: 0.493..  Test Loss: 0.444..  Test Accuracy: 0.834
# Epoch: 2/2..  Training Loss: 0.500..  Test Loss: 0.466..  Test Accuracy: 0.833
# Epoch: 2/2..  Training Loss: 0.493..  Test Loss: 0.440..  Test Accuracy: 0.842
# Epoch: 2/2..  Training Loss: 0.493..  Test Loss: 0.442..  Test Accuracy: 0.840
# Epoch: 2/2..  Training Loss: 0.554..  Test Loss: 0.465..  Test Accuracy: 0.834

# %%
print("Our model: \n\n", model, '\n')
print("The state dict keys: \n\n", model.state_dict().keys())
# Out:
# Our model:
#
#  Network(
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=256, bias=True)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (output): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
#
# The state dict keys:
#
#  odict_keys(['hidden_layers.0.weight', 'hidden_layers.0.bias', 'hidden_layers.1.weight', 'hidden_layers.1.bias', 'hidden_layers.2.weight', 'hidden_layers.2.bias', 'output.weight', 'output.bias'])

# %%
torch.save(model.state_dict(), 'checkpoint.pth')

# %%
state_dict = torch.load('checkpoint.pth')
print(state_dict.keys())
# Out:
# odict_keys(['hidden_layers.0.weight', 'hidden_layers.0.bias', 'hidden_layers.1.weight', 'hidden_layers.1.bias', 'hidden_layers.2.weight', 'hidden_layers.2.bias', 'output.weight', 'output.bias'])

# %%
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
# Use the same architecture as the saved model
model = fc_model.Network(784, 10, [512, 256, 128])
# Load the state_dict without errors
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
checkpoint = {'input_size': 784,
              'output_size': 10,
              'hidden_layers': [each.out_features for each in model.hidden_layers],
              'state_dict': model.state_dict()}

torch.save(checkpoint, 'checkpoint.pth')

# %%
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = fc_model.Network(checkpoint['input_size'],
                             checkpoint['output_size'],
                             checkpoint['hidden_layers'])
    model.load_state_dict(checkpoint['state_dict'])
    
    return model

# %%
model = load_checkpoint('checkpoint.pth')
print(model)
# Out:
# Network(
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=256, bias=True)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (output): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
